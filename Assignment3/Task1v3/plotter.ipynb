# %%
from matplotlib import pyplot as plt
import math

# %% [markdown]
# ##### Task a

# %%
def load(nodes): 
    return 1/4000 * nodes

def formula(load):
    return load * math.exp(-2*load)

x_theoretical = [x * 4000 for x in [load(1000), load(2000), load(3000), load(4000), load(5000), load(6000), load(7000), load(8000), load(9000), load(10000)]]
y_theoretical = [formula(x / 4000) for x in x_theoretical]

x_simulated = [x * 4000 for x in [0.25096385799816917, 0.5013081151440802, 0.7488674245145421, 0.9994306093330195, 1.2392998101365362, 1.4906657088757327, 1.7628955015857584, 1.998283864662526, 2.2361638947357094, 2.494360112838255, ]]
y_simulated = [0.1613998209110052, 0.195765805625205, 0.1796927019648158, 0.14599627010624386, 0.1116998419606731, 0.07656396442826971, 0.05313329729842829, 0.03823316290727335, 0.024866489532408505, 0.017366639132103442, ]

# Old
# x_simulated = [0.2469, 0.5005, 0.7496, 1.0035, 1.2510, 1.5053, 1.7492, 2.0000, 2.2450, 2.4970]
# y_simulated = [0.1781, 0.1821, 0.1662, 0.1433, 0.1195, 0.0972, 0.0794, 0.0623, 0.0497, 0.0388]

# Plot with dots and lines
plt.plot(x_theoretical, y_theoretical, 'r.-')
plt.plot(x_simulated, y_simulated, 'b.-')

# Add legend
plt.legend(['Theoretical', 'Simulated'])

# Add title
plt.title('Theoretical vs Simulated')

# Add axis labels
plt.xlabel('Load (Number of nodes)')
plt.ylabel('Thoughput')
# Out:
# Text(0, 0.5, 'Thoughput')

# %% [markdown]
# #### Task 2

# %%
y_mid = [0.35893022640010597, 0.6083883443355338, 0.7619972628140038, 0.8534038422919874, 0.9103171417101565, 0.9490980809289545, 0.9698020270910297, 0.9809008408958455, 0.988932900143902, 0.9930357835077729, ]
y_error = [0.02163634965796969, 0.015624355739890794, 0.01109200504691737, 0.008021376406533652, 0.005794349067353852, 0.004055975034856054, 0.0029198547210781177, 0.0021894304714077024, 0.0015795518789601427, 0.001191850870020431, ]
x = [x * 4000 for x in [0.25199633135548344, 0.4997612213008268, 0.7464876015038486, 1.0016909602191355, 1.2502589667620787, 1.4956794665955369, 1.7372760496006212, 2.0031055248521334, 2.2464974073718635, 2.4951922491082277, ]]

# Old
# y_mid = [0.3643, 0.5681, 0.7138, 0.7723, 0.8329, 0.8811, 0.9037, 0.9273, 0.9455, 0.9578]
# y_error = [0.019, 0.013,0.0103, 0.0082, 0.0065, 0.0051, 0.0043, 0.0036, 0.0029, 0.0024]
# y_error_2 = [0.021779375291881547, 0.01595425047819111, 0.012137403791390187, 0.00961955815179858, 0.007646768538674932, 0.006163077462699567, 0.005093916690120945, 0.004154163530326819, 0.003416283727353196, 0.002890005904211399]
# x = [0.2499, 0.4958, 0.6976, 0.9927, 1.2652, 1.5443, 1.7477, 1.9963, 2.2554, 2.4889]

# Plot x and y with error bars
plt.errorbar(x, y_mid, yerr=y_error, fmt='b.',  ecolor='red', capsize=2)

# Add title
plt.title('Packet loss probability vs Load')

# Add labels
plt.xlabel('Load (Number of nodes)')
plt.ylabel('Packet loss probability')
# Out:
# Text(0, 0.5, 'Packet loss probability')

# %% [markdown]
# #### Task 3

# %%
def load(nodes): 
    return 1/4000 * nodes

def formula(load):
    return load * math.exp(-2*load)

x_s1 = [x * 4000 for x in [0.25096385799816917, 0.5013081151440802, 0.7488674245145421, 0.9994306093330195, 1.2392998101365362, 1.4906657088757327, 1.7628955015857584, 1.998283864662526, 2.2361638947357094, 2.494360112838255, ]]
y_s1 = [0.1613998209110052, 0.195765805625205, 0.1796927019648158, 0.14599627010624386, 0.1116998419606731, 0.07656396442826971, 0.05313329729842829, 0.03823316290727335, 0.024866489532408505, 0.017366639132103442, ]

# lb=0.1, ub=1.0
x_s2_1 = [x * 4000 for x in [0.2466187750617542, 0.5093305293606055, 0.749766198220689, 1.0049741114655142, 1.2457663122977622, 1.492395599269165, 1.7479607138634616, 2.0009295794821766, 2.243896528615544, 2.493224635890829, ]]
y_s2_1 = [0.17648958155858743, 0.24559864792728672, 0.242067563019064, 0.20199479653336705, 0.15576662235751595, 0.11309966649513707, 0.08316638343769593, 0.052599025078260093, 0.03633327712451451, 0.02436625590037429, ]
# y_s2_1 = [0.17054218302890087, 0.18385758409480157, 0.16896041007189858, 0.13567861454986113, 0.0978215703294722, 0.0658536318616992, 0.042457730358748426, 0.025610568987215695, 0.015880115155957525, 0.009752851001770825, ]

# lb=0.4, ub=1.4
x_s2_2 = [x * 4000 for x in [0.2504281953618044, 0.4988214520788276, 0.7461625365063153, 0.9964644002112388, 1.2464282092755672, 1.4760249354643071, 1.7606606895736856, 2.0104233956112996, 2.252044502362601, 2.504999684842856, ]]
y_s2_2 = [0.19669596443897347, 0.27139353577185527, 0.27076516792677235, 0.2262328187674342, 0.17316595478262164, 0.1279992717459619, 0.0823330538289853, 0.053433069208378176, 0.03516580006797424, 0.02219999720699058, ]

# lb=0.9, ub=1.1
x_s2_3 = [x * 4000 for x in [0.24826058031042197, 0.4992000793327432, 0.7437996767538636, 0.9840808765806845, 1.2524079011017244, 1.5055709771025387, 1.7641991912847146, 1.9793658063866002, 2.232831820774012, 2.489163094352823, ]]
y_s2_3 = [0.19876276243045005, 0.29189654061948994, 0.30016319078197545, 0.2539291000412317, 0.1944989801692878, 0.1390660070077006, 0.09413298524086068, 0.06213224923602675, 0.038199831681027, 0.02553280624652674, ]

# lb=1, ub=1
x_s2_4 = [x * 4000 for x in [0.2556164647603157, 0.501799892788233, 0.7620764647031658, 0.9981532748715535, 1.2564985706668959, 1.4956897717099982, 1.7427877100450717, 1.9986711790746408, 2.250465905267955, 2.510126835080167, ]]
y_s2_4 = [0.2048159473810417, 0.29719926722598633, 0.3049590787081279, 0.2641980799123857, 0.19799913816585024, 0.14069998335883682, 0.09896651612308464, 0.06556640250382359, 0.04229975900625909, 0.027599758238933476, ]

# Plot with dots and lines
plt.plot(x_s1, y_s1, 'r.--')
plt.plot(x_s2_1, y_s2_1, 'b.-')
plt.plot(x_s2_2, y_s2_2, 'g.-')
plt.plot(x_s2_3, y_s2_3, 'y.-')
plt.plot(x_s2_4, y_s2_4, 'm.-')

# Add legend
plt.legend(['Strategy 1', 'Strategy 2 (lb=0.1, ub=1.0)', 'Strategy 2 (lb=0.4, ub=1.4)', 'Strategy 2 (lb=0.9, ub=1.1)', 'Strategy 2 (lb=1, ub=1)'])

# Add title
plt.title('Different strategies')

# Add axis labels
plt.xlabel('Load (Number of nodes)')
plt.ylabel('Thoughput')
# Out:
# Text(0, 0.5, 'Thoughput')

# %%
y_mid = [0.3686507936507937, 0.6182885346495031, 0.7603482920294709, 0.8499883531330072, 0.9108190252746081, 0.9461133891959351, 0.9655979585180069, 0.980430984274898, 0.9879813042510572, 0.992692636528802, ]
y_error = [0.021750416380186308, 0.01555267137580205, 0.01118168066654814, 0.008074684823410668, 0.00576867759697458, 0.004178403557290127, 0.0031295241471164287, 0.0022149294734624438, 0.00164541427978865, 0.001220282867556352, ]
x = [x * 4000 for x in [0.25199633135548344, 0.4997612213008268, 0.7464876015038486, 1.0016909602191355, 1.2502589667620787, 1.4956794665955369, 1.7372760496006212, 2.0031055248521334, 2.2464974073718635, 2.4951922491082277, ]]

y_mid_2 =  [0.2843627517232058, 0.5178010471204189, 0.6771426031294452, 0.7990049751243781, 0.8749632087335777, 0.9242160278745645, 0.9524209081027479, 0.9737127055256626, 0.9838079534144422, 0.9902270114174175, ]
y_error_2 = [0.02055807168077269, 0.015845975625377276, 0.012220215232717638, 0.009047108617523097, 0.006706885506628986, 0.00490295886579511, 0.003644025447691999, 0.002559728337073408, 0.0019069079410530538, 0.001410009875383104, ]
x_2 = [x * 4000 for x in [0.24505873948569232, 0.49876712393360134, 0.7411126577130394, 0.9957433281124108, 1.2562386449407015, 1.5052579590922228, 1.7584652712824818, 1.9989430251182836, 2.246065610104414, 2.4897963994269947, ]]

y_mid_3 = [0.21456142686010915, 0.4559305045105245, 0.6371230734867098, 0.7729644744764836, 0.8610702537908165, 0.9132810912129355, 0.9532374100719424, 0.9734219819939317, 0.9843849444222429, 0.9911377245508982, ]
y_error_3 = [0.018565699201951114, 0.015959681493796434, 0.01259792044881673, 0.009497749882439599, 0.007011449763507736, 0.00524247649793426, 0.003601112472601282, 0.002567393703834271, 0.0018697599496510296, 0.001340174036324931, ]  
x_3 = [x * 4000 for x in [0.2528609827720489, 0.4947542064576887, 0.7520599675304208, 0.9969084803688854, 1.2369255394181304, 1.4981254034086218, 1.7484645051356678, 2.0022940207361706, 2.2433943745888865, 2.4967593179936114, ]]

y_mid_4 = [0.21952201933404936, 0.46704947586298995, 0.6503988527381912, 0.777461640077228, 0.8720623852234317, 0.9244819341126461, 0.958319162604391, 0.974166821037032, 0.9850115697544226, 0.9921124874455975, ]
y_error_4 = [0.018801201546951564, 0.015980800998588812, 0.012513351973132289, 0.009489596583942465, 0.006754932798364916, 0.004873548364398566, 0.003405452561093292, 0.0025519250016054163, 0.0018403313634374186, 0.0012689629470505374, ] 
x_4 = [x * 4000 for x in [0.24772898064360713, 0.49863158890745757, 0.7478965240915572, 1.0051641298324365, 1.2373904506065043, 1.508232935988892, 1.7526947435279498, 1.9891998784088816, 2.2562552180133646, 2.5056279970722692, ]]

y_mid_5 = [0.20419872212804802, 0.4372259864487844, 0.6527577308314745, 0.7858073134079145, 0.8786576469027723, 0.9305803173471207, 0.9615943692142912, 0.9794366338119778, 0.9884173887284308, 0.9936258366089451, ]
y_error_5 = [0.01804452790548875, 0.015848206158286693, 0.012342745200581639, 0.009293606082886482, 0.0065926534323468245, 0.004703450705842306, 0.003294542171460428, 0.0022718879604664956, 0.0016142074974036147, 0.0011368419158975709, ]
x_5 = [x * 4000 for x in [0.24855217980547684, 0.4902828940874984, 0.7502934536208065, 0.9902148129575281, 1.2592123184690533, 1.494960538033364, 1.7634177015201336, 1.9842889952029144, 2.268757398009591, 2.5120121987547512, ]]

# Plot x and y with error bars
plt.errorbar(x, y_mid, yerr=y_error, fmt='r.', capsize=2)
plt.errorbar(x_2, y_mid_2, yerr=y_error_2, fmt='b.', capsize=2)
plt.errorbar(x_3, y_mid_3, yerr=y_error_3, fmt='g.', capsize=2)
plt.errorbar(x_4, y_mid_4, yerr=y_error_4, fmt='y.', capsize=2)
plt.errorbar(x_5, y_mid_5, yerr=y_error_5, fmt='m.', capsize=2)

# Add title
plt.title('Packet loss probability vs Load')

# Add legend
plt.legend(['Strategy 1', 'Strategy 2 (lb=0.1, ub=1.0)', 'Strategy 2 (lb=0.4, ub=1.4)', 'Strategy 2 (lb=0.2, ub=1.8)', 'Strategy 2 (lb=1, ub=3)'])


# Add labels
plt.xlabel('Load (Number of nodes)')
plt.ylabel('Packet loss probability')
# Out:
# Text(0, 0.5, 'Packet loss probability')

# %% [markdown]
# #### Task 4

# %%
x_radius = [6, 7, 8, 9, 10, 11]
y_throughput = [0.27772365370361995, 0.2999927082679554, 0.3181293015900165, 0.3321528288843393, 0.3410572805781838, 0.34306508886982806, ]


# Plot with dots and lines
plt.plot(x_radius, y_throughput, 'r.-')


# Add title
plt.title('Throughput vs. Radius (2000 nodes)')

# Add legend
plt.legend(['Strategy 2 (lb=1, ub=1)'])

# Add axis labels
plt.xlabel('Radius')
plt.ylabel('Thoughput')
# Out:
# Text(0, 0.5, 'Thoughput')
